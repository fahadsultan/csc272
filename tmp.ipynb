# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("patrickzel/flight-delay-and-cancellation-dataset-2019-2023")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 140M/140M [00:04<00:00, 31.0MB/s]
# Extracting files...
# Path to dataset files: /Users/fsultan/.cache/kagglehub/datasets/patrickzel/flight-delay-and-cancellation-dataset-2019-2023/versions/7

# %%
ls -lt /Users/fsultan/.cache/kagglehub/datasets/patrickzel/flight-delay-and-cancellation-dataset-2019-2023/versions/7
# Out:
# total 1212560
# -rw-r--r--  1 fsultan  staff  614140650 Oct 27 13:27 flights_sample_3m.csv
# -rw-r--r--  1 fsultan  staff       5011 Oct 27 13:27 dictionary.html

# %%
mv /Users/fsultan/.cache/kagglehub/datasets/patrickzel/flight-delay-and-cancellation-dataset-2019-2023/versions/7/*.csv .

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("antonkozyriev/game-recommendations-on-steam")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 660M/660M [00:25<00:00, 27.4MB/s]
# Extracting files...
# Path to dataset files: /Users/fsultan/.cache/kagglehub/datasets/antonkozyriev/game-recommendations-on-steam/versions/28
